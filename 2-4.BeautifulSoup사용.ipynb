# %% [markdown]
# # BeautifulSoup 사용방법

# %%
# !pip install beautifulSoup4
# Out:
# Requirement already satisfied: beautifulSoup4 in c:\users\miran\appdata\local\programs\python\python39\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\miran\appdata\local\programs\python\python39\lib\site-packages (from beautifulSoup4) (2.3.2.post1)

# %%
# bs4라는 패키지로부터 BeautifulSoup라는 모듈을 임포트
from bs4 import BeautifulSoup

# %%
html = """
<html>
    <body>
        <h1 id='title'>[1]크롤링이란?</h1>
        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것<br></p>
        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것<br></p>
        <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
        <a href = 'http://www.facebook.com'> 바로가기 </a> 
    </body>
</html>
"""

# %%
# BeautifulSoup 인스턴스 생성. 두번째 매개변수는 분석할 분석기(parser)의 종류.
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <html>
# <body>
# <h1 id="title">[1]크롤링이란?</h1>
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것<br/></p>
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것<br/></p>
# <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
# <a href="http://www.facebook.com"> 바로가기 </a>
# </body>
# </html>

# %% [markdown]
# ## 태그안의 정보 찾기
#
# * soup.select('태그명') : 태그를 입력으로 사용할 경우
# * soup.select('.클래스명') : 클래스를 입력으로 사용할 경우
# * soup.select('#아이디') : ID를 입력으로 사용할 경우
# * soup.select('상위태그 하위태그') : 자손 관계 (띄어쓰기)
# * soup.select('상위태그 > 하위태그') : 자식 관계 ( > )

# %%
# <body> 태그를 입력
soup.select('body')
# Out:
# [<body>
#  <h1 id="title">[1]크롤링이란?</h1>
#  <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것<br/></p>
#  <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것<br/></p>
#  <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
#  <a href="http://www.facebook.com"> 바로가기 </a>
#  </body>]

# %%
#장바구니 추출

a=soup.select('.cssstyle')#리스트로 반환?
a#타입이 reslutSet이다.
# Out:
# [<p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것<br/></p>,
#  <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것<br/></p>]

# %%
a=soup.select('.cssstyle')[1]
a.get_text()#css로 먼저 추출하고 , [0]인덱스, 값
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'

# %%
atag = soup.select('a')[0]
atag
# Out:
# <a href="http://www.facebook.com"> 바로가기 </a>

# %%
atag['href']#어트리뷰트를 대괄호에 넣어주면 추출이 됨.
# Out:
# 'http://www.facebook.com'
